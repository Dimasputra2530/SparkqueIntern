# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimasputra2530/SparkqueIntern/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT LIBRARY

# %%
import pandas as pd
import numpy as npe
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %% [markdown]
# #LOAD DATASET

# %%
df = pd.read_csv('orders.csv')

# %%
df.head()
# Out:
#   Coffee Type Roast Type    Size Unit Price     Sales Coffee Type Name  \
# 0         Rob          M  1.0 kg     $9.95    $19.90           Robusta
# 1         Exc          M  0.5 kg     $8.25    $41.25           Excelsa
# 2         Ara          L  1.0 kg    $12.95    $12.95           Arabica
# 3         Exc          M  1.0 kg    $13.75    $27.50           Excelsa
# 4         Rob          L  2.5 kg    $27.49    $54.97           Robusta
#
#   Roast Type Name Loyalty Card
# 0          Medium          Yes
# 1          Medium          Yes
# 2           Light          Yes
# 3          Medium           No
# 4           Light           No

# %% [markdown]
# #Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Coffee Type       1000 non-null   object
#  1   Roast Type        1000 non-null   object
#  2   Size              1000 non-null   object
#  3   Unit Price        1000 non-null   object
#  4   Sales             1000 non-null   object
#  5   Coffee Type Name  1000 non-null   object
#  6   Roast Type Name   1000 non-null   object
#  7   Loyalty Card      1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        Coffee Type Roast Type    Size Unit Price     Sales Coffee Type Name  \
# count         1000       1000    1000       1000      1000             1000
# unique           4          3       4         40       196                4
# top            Ara          M  0.5 kg     $5.97    $17.91           Arabica
# freq           264        334     268         47        21              264
#
#        Roast Type Name Loyalty Card
# count             1000         1000
# unique               3            2
# top             Medium           No
# freq               334          521

# %%
df.isnull().sum()
# Out:
# Coffee Type         0
# Roast Type          0
# Size                0
# Unit Price          0
# Sales               0
# Coffee Type Name    0
# Roast Type Name     0
# Loyalty Card        0
# dtype: int64

# %% [markdown]
# #Check for duplicate data

# %%
df.duplicated().sum()
# Out:
# np.int64(519)

# %% [markdown]
# #Remove missing values

# %%
df = df.dropna()

# %% [markdown]
# #Remove duplicate

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Detect & Handle Outliers

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # Remove outliers
    df = df[(df[col] >= lower) & (df[col] <= upper)]

print("\nOutliers removed using IQR.")
# Out:
# Outliers removed using IQR.

# %% [markdown]
# # Incorrect Data Types

# %%
# Pastikan kolom berbentuk string dulu
df["Unit Price"] = df["Unit Price"].astype(str)
df["Sales"] = df["Sales"].astype(str)

# Bersihkan simbol $ dan koma
df["Unit Price"] = df["Unit Price"].str.replace("$", "", regex=False).str.replace(",", "")
df["Sales"] = df["Sales"].str.replace("$", "", regex=False).str.replace(",", "")

# Convert ke float
df["Unit Price"] = pd.to_numeric(df["Unit Price"], errors="coerce")
df["Sales"] = pd.to_numeric(df["Sales"], errors="coerce")

print(df.dtypes)
# Out:
# Coffee Type          object
# Roast Type           object
# Size                 object
# Unit Price          float64
# Sales               float64
# Coffee Type Name     object
# Roast Type Name      object
# Loyalty Card         object
# dtype: object
